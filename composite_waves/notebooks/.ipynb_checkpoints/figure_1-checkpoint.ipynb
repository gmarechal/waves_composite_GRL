# %% [markdown]
# # Figure 1
# ##### g.marechal (August 2025, Toulouse)

# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr

import matplotlib.ticker as mticker
import matplotlib.colors as mcolors
from matplotlib.patches import Ellipse
from scipy.ndimage import gaussian_filter
import time

import cmocean

# %%
pol = 'cyclonic' # polarization
path_data = '../data/' + pol +"/"
path_output = '../figures/'

# %% [markdown]
# ### Load Data

# %%
suffix = '.nc'

compo_hs_full_swell = xr.open_dataset(path_data + 'composite_hs_swell_full' + suffix)
compo_hs_full_windsea = xr.open_dataset(path_data + 'composite_hs_windsea_full' + suffix)
compo_hs_noow_swell = xr.open_dataset(path_data + 'composite_hs_swell_noow' + suffix)
compo_hs_noow_windsea = xr.open_dataset(path_data + 'composite_hs_windsea_noow' + suffix)

std_compo_hs_full_swell = xr.open_dataset(path_data + 'composite_std_hs_swell_full' + suffix)
std_compo_hs_full_windsea = xr.open_dataset(path_data + 'composite_std_hs_windsea_full' + suffix)
std_compo_hs_noow_swell = xr.open_dataset(path_data + 'composite_std_hs_swell_noow' + suffix)
std_compo_hs_noow_windsea = xr.open_dataset(path_data + 'composite_std_hs_windsea_noow' + suffix)


compo_curspeed = xr.open_dataset(path_data + 'composite_cur_speed' + suffix)
compo_ucur = xr.open_dataset(path_data + 'composite_ucur' + suffix)
compo_vcur = xr.open_dataset(path_data + 'composite_vcur' + suffix)

compo_windspeed = xr.open_dataset(path_data + 'composite_wind_speed' + suffix)

# --- Load the unique variable inside every datArray
# here: composite_swell and composite_windsea are just dummy variable name
compo_hs_full_swell = compo_hs_full_swell['composite_swell']
compo_hs_full_windsea = compo_hs_full_windsea['composite_windsea']
compo_hs_noow_swell = compo_hs_noow_swell['composite_swell']
compo_hs_noow_windsea = compo_hs_noow_windsea['composite_windsea']
std_compo_hs_full_swell = std_compo_hs_full_swell['composite_swell']
std_compo_hs_full_windsea = std_compo_hs_full_windsea['composite_windsea']
std_compo_hs_noow_swell = std_compo_hs_noow_swell['composite_swell']
std_compo_hs_noow_windsea = std_compo_hs_noow_windsea['composite_windsea']

compo_curspeed = compo_curspeed['composite_swell']
compo_ucur = compo_ucur['composite_swell']
compo_vcur = compo_vcur['composite_swell']
compo_windspeed = compo_windspeed['composite_windsea']

# %% [markdown]
# ### Number of independant sample for the mean uncertainty + coupling coeff cur/hs

# %%
# --- The number of independant eddies (cyclonic), these informations are in the netcdf's attributes
# # OWA
n_real_swell_OWA = 84
n_real_windsea_OWA = 23

# NOOW
n_real_swell_NOOW = 91
n_real_windsea_NOOW = 24



# Coupling coefficients
swell_aligned = -.12
swell_opposed = .15

windsea_aligned = -0.24
windsea_opposed = 0.33

# %% [markdown]
# ### Plot Circles

# %%
theta = np.linspace(0, 2*np.pi, 100)
x_circle = np.cos(theta)
y_circle = np.sin(theta)

x_circle_small = np.cos(theta)/2.5
y_circle_small = np.sin(theta)/2.5


arrow_length = 0.8  # Adjust length as needed
x_start = 0
y_start = 0
theta_rot = 0
x_end = x_start + arrow_length * np.cos(theta_rot*(+1))
y_end = y_start + arrow_length * np.sin(theta_rot*(+1))

props1 = dict(boxstyle='round', facecolor='w', alpha=1)
props2 = dict(boxstyle='square', facecolor='w', alpha=1)

n_quiver = 15

# %% [markdown]
# ### Summary plot

# %%
plt.rcParams['font.size'] = '12'

fig, axes = plt.subplots(ncols = 2, nrows = 2, sharey = True, sharex = True, figsize = (10, 10))
ax = axes[0][0]
p_OWA = ax.pcolor(compo_hs_full_swell.x, compo_hs_full_swell.y, compo_hs_full_swell, vmin = -.06, vmax = .06, cmap = 'RdBu_r')
ax.plot([0, 0], [-1, 1], color = 'k')


plt.text(0.025, 0.88, '$\mathcal{S}^{\leftarrow}$=\n%.2f s'%swell_opposed,
     transform = ax.transAxes, bbox = props2, fontsize = 10, color = 'tomato')
plt.text(0.025, 0.035, '$\mathcal{S}^{\\rightarrow}$=\n%.2f s'%swell_aligned,
     transform = ax.transAxes, bbox = props2, fontsize = 10, color = 'teal')

ax.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 3)
ax.plot(x_circle_small, y_circle_small, color = 'w', linewidth = 1)
ax.plot(x_circle, y_circle, color = 'k', linewidth = 3)
ax.plot(x_circle, y_circle, color = 'w', linewidth = 1, linestyle = '--')
ax.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
ax.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])
ax.arrow(x_start, y_start, x_end, y_end, 
         head_width=0.2, head_length=0.2, 
         fc='white', ec='black',  linestyle = '-', linewidth =1, width = .02, zorder = 10)  # White face, black edges, thicker lines


ax.set_aspect('equal', 'box')
ax.set_title('Swell-OWA')
plt.text(0.88, 0.9, '(a)',
     transform = ax.transAxes, bbox = props1)

ax = axes[0][1]
p1 = ax.pcolor(compo_hs_full_windsea.x, compo_hs_full_windsea.y, compo_hs_full_windsea, vmin = -.06, vmax = .06, cmap = 'RdBu_r')
ax.plot([0, 0], [-1, 1], color = 'k', linestyle = '--')



plt.text(0.025, 0.88, '$\mathcal{S}^{\leftarrow}$=\n%.2f s'%windsea_opposed,
     transform = ax.transAxes, bbox = props2, fontsize = 10, color = 'tomato')
plt.text(0.025, 0.035, '$\mathcal{S}^{\\rightarrow}$=\n%.2f s'%windsea_aligned,
     transform = ax.transAxes, bbox = props2, fontsize = 10, color = 'teal')

ax.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 3)
ax.plot(x_circle_small, y_circle_small, color = 'w', linewidth = 1)
ax.plot(x_circle, y_circle, color = 'k', linewidth = 3)
ax.plot(x_circle, y_circle, color = 'w', linewidth = 1, linestyle = '--')
ax.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
ax.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])
ax.arrow(x_start, y_start, x_end, y_end, 
         head_width=0.2, head_length=0.2, 
         fc='white', ec='black',  linestyle = '--', linewidth =1, width = .02, zorder = 10) 


ax.set_title('Wind Sea-OWA')
ax.set_aspect('equal', 'box')
plt.text(0.88, 0.9, '(c)',
     transform = ax.transAxes, bbox = props1)

ax = axes[1][0]
ax.pcolor(compo_hs_noow_swell.x, compo_hs_noow_swell.y, compo_hs_noow_swell, vmin = -.01, vmax = .01, cmap = 'RdBu_r')
ax.plot([0, 0], [-1, 1], color = 'k')



ax.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 3)
ax.plot(x_circle_small, y_circle_small, color = 'w', linewidth = 1)
ax.plot(x_circle, y_circle, color = 'k', linewidth = 3)
ax.plot(x_circle, y_circle, color = 'w', linewidth = 1, linestyle = '--')
ax.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
ax.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])

ax.set_title('Swell-NOOW')
ax.set_aspect('equal', 'box')
plt.text(0.88, 0.9, '(d)',
     transform = ax.transAxes, bbox = props1)

ax = axes[1][1]
p_NOOW = ax.pcolor(compo_hs_noow_windsea.x, compo_hs_noow_windsea.y, compo_hs_noow_windsea, vmin = -.01, vmax = .01, cmap = 'RdBu_r')
ax.plot([0, 0], [-1, 1], color = 'k', linestyle = '--')

ax.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 3)
ax.plot(x_circle_small, y_circle_small, color = 'w', linewidth = 1)
ax.plot(x_circle, y_circle, color = 'k', linewidth = 3)
ax.plot(x_circle, y_circle, color = 'w', linewidth = 1, linestyle = '--')
ax.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
ax.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])

ax.set_aspect('equal', 'box')
ax.set_title('Wind Sea-NOOW')
plt.text(0.88, 0.9, '(f)',
     transform = ax.transAxes, bbox = props1)

cax = fig.add_axes([.92, .56, 0.015, 0.22])
cbar = plt.colorbar(p_OWA, cax = cax, orientation = 'vertical')
cbar.ax.set_ylabel('$H_s$ anomaly [m]')

cax = fig.add_axes([.92, .2, 0.015, 0.22])
cbar = plt.colorbar(p_NOOW, cax = cax, orientation = 'vertical')
cbar.ax.set_ylabel('$H_s$ anomaly [m]')



inset_ax1 = fig.add_axes([.435, .535, .15, .275])
inset_ax1.plot()
inset_ax1.plot(compo_hs_full_swell[:, 50], compo_hs_full_swell.y, color = 'k', linewidth = 1, label= 'swell')
inset_ax1.plot(compo_hs_full_windsea[:, 50], compo_hs_full_swell.y, color = 'k', linewidth = 1, linestyle = '--', label= 'wind sea')
inset_ax1.errorbar(compo_hs_full_swell[::10,50], std_compo_hs_full_swell.y[::10], xerr=std_compo_hs_full_swell[::10,50]/np.sqrt(n_real_swell_OWA), capsize = 5, fmt=' ', color = 'k')
inset_ax1.errorbar(compo_hs_full_windsea[::10,50], std_compo_hs_full_swell.y[::10], xerr=std_compo_hs_full_windsea[::10,50]/np.sqrt(n_real_windsea_OWA), capsize = 5, fmt=' ', color = 'k')

                   
inset_ax1.set_xlim([-.07, 0.07])
inset_ax1.set_yticks([], [])
# inset_ax1.set_xticks([], [])
inset_ax1.plot([-.5, .5], [-.4, -.4], color = 'k', alpha = .3, linewidth =.5)
inset_ax1.plot([-.5, .5], [.4, .4], color = 'k', alpha = .3, linewidth =.5)
inset_ax1.set_xticks([-0.05, 0, 0.05])
inset_ax1.set_xticklabels(['-0.05', '0', '0.05'], rotation = 30)

plt.text(0.78, 0.9, '(b)',
     transform = inset_ax1.transAxes, bbox = props1)


inset_ax2 = fig.add_axes([.435, .18, .15, .275])

inset_ax2.plot(compo_hs_noow_swell[:, 50], compo_hs_noow_swell.y, color = 'k', linewidth = 1, label= 'swell')
inset_ax2.plot(compo_hs_noow_windsea[:, 50], compo_hs_noow_windsea.y, color = 'k', linewidth = 1, linestyle = '--', label= 'wind sea')
inset_ax2.errorbar(compo_hs_noow_swell[::10,50], compo_hs_noow_swell.y[::10], xerr=std_compo_hs_noow_swell[::10,50]/np.sqrt(n_real_swell_NOOW), capsize = 5, fmt=' ', color = 'k')
inset_ax2.errorbar(compo_hs_noow_windsea[::10,50], compo_hs_noow_windsea.y[::10], xerr=std_compo_hs_noow_windsea[::10,50]/np.sqrt(n_real_swell_NOOW), capsize = 5, fmt=' ', color = 'k')



# inset_ax2.fill_betweenx(var_no_OW.y, var_no_OW.composite_swell[:, 50],  var_no_OW.composite_swell[:, 50]+std_no_OW.composite_swell[:,50]/np.sqrt(n_real_swell_NOOW), var_no_OW.composite_swell[:, 50]-std_no_OW.composite_swell[:,50]/np.sqrt(n_real_swell_NOOW), color = 'k', alpha = .3)
# inset_ax2.fill_betweenx(var_no_OW.y, var_no_OW.composite_windsea[:, 50],  var_no_OW.composite_windsea[:, 50]+std_no_OW.composite_windsea[:,50]/np.sqrt(n_real_windsea_NOOW), var_no_OW.composite_windsea[:, 50]-std_no_OW.composite_windsea[:,50]/np.sqrt(n_real_windsea_NOOW), color = 'k', alpha = .3)


inset_ax2.set_xlim([-.07, 0.07])
inset_ax2.set_yticks([], [])
inset_ax2.set_xlabel('$H_s$\nanomaly [m]')
inset_ax2.set_xticks([-0.05,0, 0.05])

inset_ax2.set_xticklabels(['-0.05', '0', '0.05'], rotation = 30)

# inset_ax2.set_xticks([], [])
inset_ax2.plot([-.5, .5], [-.4, -.4], color = 'k', alpha = .3, linewidth =.5)
inset_ax2.plot([-.5, .5], [.4, .4], color = 'k', alpha = .3, linewidth =.5)

plt.text(0.78, 0.9, '(e)',
     transform = inset_ax2.transAxes, bbox = props1)



inset_ax3 = fig.add_axes([1.1, .5617, .22, .22])
nb_quiver = 10
p3 = inset_ax3.pcolormesh(compo_curspeed.x, compo_curspeed.y, compo_curspeed, vmin = 0, vmax = .14)
inset_ax3.quiver(compo_curspeed.x[::nb_quiver], compo_curspeed.y[::nb_quiver], compo_ucur[::nb_quiver, ::nb_quiver]/compo_curspeed[::nb_quiver, ::nb_quiver],\
                  compo_vcur[::nb_quiver, ::nb_quiver]/compo_curspeed[::nb_quiver, ::nb_quiver], width = 0.008, scale = 14)

inset_ax3.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 3)
inset_ax3.plot(x_circle_small, y_circle_small, color = 'w', linewidth = 1)
inset_ax3.plot(x_circle, y_circle, color = 'k', linewidth = 3)
inset_ax3.plot(x_circle, y_circle, color = 'w', linewidth = 1, linestyle = '--')
inset_ax3.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
inset_ax3.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])
inset_ax3.plot([0, 0], [-1, 1], color = 'k')
inset_ax3.set_aspect('equal', 'box')

cax = fig.add_axes([1.1, .81, .215, 0.015])
cbar = plt.colorbar(p3, cax = cax, orientation = 'horizontal', ticks= [0, .07, 0.14])
cbar.ax.set_title('Current anomaly [m/s]', fontsize = 11)

plt.text(0.865, 0.9, '(g)',
     transform = inset_ax3.transAxes, bbox = props1)
inset_ax4 = fig.add_axes([1.1, .208, .22, .22])

p3 = inset_ax4.pcolormesh(compo_windspeed.x, compo_windspeed.y, compo_windspeed, vmin = -.2, vmax = .2, cmap = 'PuOr_r')

inset_ax4.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 3)
inset_ax4.plot(x_circle_small, y_circle_small, color = 'w', linewidth = 1)
inset_ax4.plot(x_circle, y_circle, color = 'k', linewidth = 3)
inset_ax4.plot(x_circle, y_circle, color = 'w', linewidth = 1, linestyle = '--')
inset_ax4.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
inset_ax4.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])
inset_ax4.plot([0, 0], [-1, 1], color = 'k')
inset_ax4.set_aspect('equal', 'box')

cax = fig.add_axes([1.1, .455, .215, 0.015])
cbar = plt.colorbar(p3, cax = cax, orientation = 'horizontal')
cbar.ax.set_title('Rel. WSPD anomaly [m/s]', fontsize = 11)
plt.text(0.865, 0.9, '(i)',
     transform = inset_ax4.transAxes, bbox = props1)

inset_ax5 = fig.add_axes([1.36, .5617, .13, .22])


inset_ax5.plot(compo_curspeed[:, 50], compo_curspeed.y, color = 'k', linewidth = 1)
inset_ax5.set_xlim([0, 0.17])
inset_ax5.set_yticks([], [])
inset_ax5.set_xticks([0.0, 0.07, 0.14])
inset_ax5.set_xticklabels(['0', '0.07', '0.14'], rotation = 20)

inset_ax5.set_xlabel('Current\nanomaly [m/s]')
# inset_ax5.set_xticks([], [])
# inset_ax5.plot([-.1, .1], [-.4, -.4], color = 'k', alpha = .3, linewidth =.5)
# inset_ax5.plot([-.1, .1], [.4, .4], color = 'k', alpha = .3, linewidth =.5)

plt.text(0.78, 0.9, '(h)',
     transform = inset_ax5.transAxes, bbox = props1)

inset_ax6 = fig.add_axes([1.36, .208, .13, .22])

inset_ax6.plot(compo_windspeed[:, 50], compo_windspeed.y, color = 'k', linewidth = 1)
# inset_ax6.set_xlim([-0.08, +0.08])
inset_ax6.set_yticks([], [])
inset_ax6.set_xlabel('Rel. WSPD\nanomaly [m/s]')
inset_ax6.set_xticks([-0.1, 0, 0.1])
inset_ax6.set_xticklabels(['-0.1', '0', '0.1'], rotation = 90)

plt.text(0.18, 0.9, '(j)',
     transform = inset_ax6.transAxes, bbox = props1)


plt.subplots_adjust(wspace=.8, hspace=-.15)
plt.savefig(path_output + '/Fig1.png', dpi = 300, bbox_inches = 'tight')

# %% [markdown]
# ### Sketch of Concertina Effect

# %%
fig, ax_inset_5 = plt.subplots()
ax_inset_5.text(-.78, .21, 'Mean Wave Direction\n(or Wind Direction)', bbox=dict(boxstyle="round", ec='k', fc='white'), fontsize = 8)
ax_inset_5.text(-.3, .78, 'Opposed current\nSteeper waves', bbox=dict(boxstyle="round", ec='k', fc='white'), fontsize = 8)
ax_inset_5.text(-.3, -.87, 'Aligned current\nSmoother waves', bbox=dict(boxstyle="round", ec='k', fc='white'), fontsize = 8)

ax_inset_5.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 3)
ax_inset_5.plot(x_circle_small, y_circle_small, color = 'w', linewidth = 1)
ax_inset_5.plot(x_circle, y_circle, color = 'k', linewidth = 3)
ax_inset_5.plot(x_circle, y_circle, color = 'w', linewidth = 1, linestyle = '--')

ax_inset_5.arrow(-.75, 0, 1.25, 0, 
         head_width=0.2, head_length=0.2, 
         fc='white', ec='black', lw=2, width =0.1, zorder = 10)  # White face, black edges, thicker lines
ax_inset_5.arrow(0.3, .6, -.5, 0, 
         head_width=0.2, head_length=0.2, 
         fc='k', ec='black',  zorder = 10, alpha = .5)  # White face, black edges, thicker lines

ax_inset_5.arrow(-.3, -.6, .5, 0, 
         head_width=0.2, head_length=0.2, 
         fc='k', ec='black',  zorder = 10, alpha = .5)  # White face, black edges, thicker lines

ax_inset_5.set_aspect('equal', 'box')
red_ellipse = Ellipse((0, -0.42), width=0.8, height=0.7, color='blue', alpha = .4)
ax_inset_5.add_patch(red_ellipse)

# Add a blue ellipse at the top
blue_ellipse = Ellipse((0, 0.42), width=0.8, height=0.7, color='red', alpha = .4)
ax_inset_5.add_patch(blue_ellipse)

ax_inset_5.plot(x_circle_small, y_circle_small, color = 'k', linewidth = 3)
ax_inset_5.plot(x_circle_small, y_circle_small, color = 'w', linewidth = 1)
ax_inset_5.plot(x_circle, y_circle, color = 'k', linewidth = 3)
ax_inset_5.plot(x_circle, y_circle, color = 'w', linewidth = 1, linestyle = '--')
ax_inset_5.set_xticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'], rotation = 90)
ax_inset_5.set_yticks([-1, -.4, 0, .4, 1], ['-2.5$R_{max}$', '-$R_{max}$', '0', '$R_{max}$', '2.5$R_{max}$'])
